# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_excel(r"C:\Users\User\Downloads\Dataset (3).xlsx")

# %%
df.head()
# Out:
#   Month  WeekOfMonth  DayOfWeek    Make AccidentArea DayOfWeekClaimed  \
# 0   Dec            5  Wednesday   Honda        Urban          Tuesday
# 1   Jan            3  Wednesday   Honda        Urban           Monday
# 2   Oct            5     Friday   Honda        Urban         Thursday
# 3   Jun            2   Saturday  Toyota        Rural           Friday
# 4   Feb            1   Saturday   Honda        Urban           Monday
#
#   MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus      ...       \
# 0          Jan                   1  Female        Single      ...
# 1          Jan                   4    Male        Single      ...
# 2          Nov                   2    Male       Married      ...
# 3          Jul                   1    Male       Married      ...
# 4          Feb                   3    Male       Married      ...
#
#    AgeOfPolicyHolder PoliceReportFiled WitnessPresent AgentType  \
# 0           26 to 30                No             No  External
# 1           31 to 35               Yes             No  External
# 2           41 to 50                No             No  External
# 3           51 to 65               Yes             No  External
# 4           36 to 40                No             No  External
#
#   NumberOfSuppliments  AddressChange_Claim  NumberOfCars  Year  BasePolicy  \
# 0                none               1 year        3 to 4  1994   Liability
# 1                none            no change     1 vehicle  1994   Collision
# 2                none            no change     1 vehicle  1994   Collision
# 3         more than 5            no change     1 vehicle  1994   Liability
# 4              1 to 2            no change     1 vehicle  1994   Collision
#
#       ClaimSize
# 0  55526.069421
# 1  59294.455571
# 2  71756.941320
# 3   7584.153493
# 4  98545.374339
#
# [5 rows x 34 columns]

# %%
df.describe()
# Out:
#         WeekOfMonth  WeekOfMonthClaimed           Age  FraudFound_P  \
# count  11565.000000        11565.000000  11560.000000  11565.000000
# mean       2.784003            2.701167     39.899567      0.059230
# std        1.284854            1.258153     13.590556      0.236066
# min        1.000000            1.000000      0.000000      0.000000
# 25%        2.000000            2.000000     31.000000      0.000000
# 50%        3.000000            3.000000     38.000000      0.000000
# 75%        4.000000            4.000000     49.000000      0.000000
# max        5.000000            5.000000     80.000000      1.000000
#
#        PolicyNumber     RepNumber    Deductible  DriverRating          Year  \
# count  11565.000000  11565.000000  11565.000000  11559.000000  11565.000000
# mean    7710.474449      8.469780    407.617812      2.493468   1994.865975
# std     4453.762219      4.618952     43.397393      1.118102      0.801798
# min        1.000000      1.000000    300.000000      1.000000   1994.000000
# 25%     3851.000000      4.000000    400.000000      1.000000   1994.000000
# 50%     7712.000000      8.000000    400.000000      3.000000   1995.000000
# 75%    11542.000000     12.000000    400.000000      3.000000   1996.000000
# max    15420.000000     16.000000    700.000000      4.000000   1996.000000
#
#            ClaimSize
# count   11565.000000
# mean    22955.978035
# std     26988.811719
# min         0.000000
# 25%      4148.845001
# 50%      8130.994563
# 75%     46299.646944
# max    141394.159289

# %%
import seaborn as sns
sns.countplot("FraudFound_P",data=df)

# %%
#Policy Holder Personal data: Sex, Marital Status, Age

#SEX

fig, ax = plt.subplots(1, 2, figsize = (18, 8))
df["Sex"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Number Of People By Sex")
ax[0].set_ylabel("Population")
sns.countplot("Sex", hue = "FraudFound_P", data=df, ax = ax[1])
ax[1].set_title("Sex:Fraud vs Not-Fraud")
plt.show()

# %%
#MARITAL STATUS

fig, ax = plt.subplots(1, 2, figsize = (18, 8))
df["MaritalStatus"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Number Of People By Marital Status")
ax[0].set_ylabel("Count")
sns.countplot("MaritalStatus", hue = "FraudFound_P", data=df, ax = ax[1])
ax[1].set_title("MaritalStatus:Fraud vs Not-Fraud")
plt.show()

# %%
# AGE

fig, ax = plt.subplots(1, 2, figsize = (18, 10))
df[df["FraudFound_P"] ==1]["Age"].plot.hist(ax = ax[0], bins = 20, edgecolor = "black", color = "blue")
ax[0].set_title("Not Fraud")
domain_1 = list(range(0, 85, 5))
ax[0].set_xticks(domain_1)
df[df["FraudFound_P"] == 0]["Age"].plot.hist(ax = ax[1], bins = 20, edgecolor = "black", color = "green")
ax[1].set_title("Fraud")
domain_2 = list(range(0, 85, 5))
ax[1].set_xticks(domain_2)
plt.show()

# %%
# EFFECT OF SEX AND MARITAL STATUS ON Fraud Claims

sns.barplot(x = "Sex", y = "FraudFound_P", hue = "MaritalStatus", data = df)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Characteristics of the Vehicle on Fraud Claims(Make,Age of Vehicle,Vehicle Category,Vehicle Price)

#Make

fig, ax = plt.subplots(1, 2, figsize = (30, 8))
df["Make"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Make")
ax[0].set_ylabel("Number ")
sns.countplot("Make", hue = "FraudFound_P", data = df, ax = ax[1])
ax[1].set_title("Make on determining if a claim if Fraud or not")
plt.show()

# %%
#Age of Vehicle

fig, ax = plt.subplots(1, 2, figsize = (18, 8))
df["AgeOfVehicle"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Age Of Vehicle")
ax[0].set_ylabel("Number")
sns.countplot("AgeOfVehicle", hue = "FraudFound_P", data = df, ax = ax[1])
ax[1].set_title("Age Of Vehicle on determining if a claim if Fraud or not")
plt.show()

# %%
#Category of Vehicle

fig, ax = plt.subplots(1, 2, figsize = (18, 8))
df["VehicleCategory"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Vehicle Category")
ax[0].set_ylabel("Number")
sns.countplot("VehicleCategory", hue = "FraudFound_P", data = df, ax = ax[1])
ax[1].set_title("Vehicle Category on determining if a claim if Fraud or not")
plt.show()

# %%
#Vehicle Price

fig, ax = plt.subplots(1, 2, figsize = (20, 12))
df["VehiclePrice"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Vehicle Price")
ax[0].set_ylabel("Price")
sns.countplot("VehiclePrice", hue = "FraudFound_P", data = df, ax = ax[1])
ax[1].set_title("Vehicle Price on determining if a claim if Fraud or not")
plt.show()

# %%
# EFFECT OF VEHICLE DATA ON Fraud Claims

sns.barplot(x = "VehicleCategory", y = "FraudFound_P", hue = "VehiclePrice", data = df)
plt.show()

# %%
# Effect of Claim Data on Fraud Claims (Accident Area, Claim Date, Fault, Past Number of Claims, Police Report Filed, Witness Present,Address Change Claim, Claim Size)

#Accident Area

fig, ax = plt.subplots(1, 2, figsize = (18, 8))
df["AccidentArea"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Accident Area")
ax[0].set_ylabel("Number")
sns.countplot("AccidentArea", hue = "FraudFound_P", data = df, ax = ax[1])
ax[1].set_title("Accident Area on determining if a claim if Fraud or not")
plt.show()

# %%
#Fault

fig, ax = plt.subplots(1, 2, figsize = (18, 8))
df["Fault"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Fault")
ax[0].set_ylabel("Number")
sns.countplot("Fault", hue = "FraudFound_P", data = df, ax = ax[1])
ax[1].set_title("Fault on determining if a claim if Fraud or not")
plt.show()

# %%
#Past Number of Claims

fig, ax = plt.subplots(1, 2, figsize = (18, 8))
df["PastNumberOfClaims"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Past Number of Claims")
ax[0].set_ylabel("Number")
sns.countplot("PastNumberOfClaims", hue = "FraudFound_P", data = df, ax = ax[1])
ax[1].set_title("Past number of claims on determining if a claim if Fraud or not")
plt.show()

# %%
#Police Report Filed

fig, ax = plt.subplots(1, 2, figsize = (18, 8))
df["PoliceReportFiled"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Police Report Filed")
ax[0].set_ylabel("Number")
sns.countplot("PoliceReportFiled", hue = "FraudFound_P", data = df, ax = ax[1])
ax[1].set_title("Police Report Filed on determining if a claim if Fraud or not")
plt.show()

# %%
#Witness Present

fig, ax = plt.subplots(1, 2, figsize = (18, 8))
df["WitnessPresent"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Witness Present")
ax[0].set_ylabel("Number")
sns.countplot("WitnessPresent", hue = "FraudFound_P", data = df, ax = ax[1])
ax[1].set_title("Witnesses Present on determining if a claim if Fraud or not")
plt.show()

# %%
#Address Change Claim

fig, ax = plt.subplots(1, 2, figsize = (18, 8))
df["AddressChange_Claim"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Address Change Claim")
ax[0].set_ylabel("Number")
sns.countplot("AddressChange_Claim", hue = "FraudFound_P", data = df, ax = ax[1])
ax[1].set_title("Address Change Claim on determining if a claim if Fraud or not")
plt.show()

# %%
# Claim Size

fig, ax = plt.subplots(1, 2, figsize = (18, 10))
df[df["FraudFound_P"] ==0]["ClaimSize"].plot.hist(ax = ax[0], bins = 20, edgecolor = "black", color = "blue")
ax[0].set_title("Not Fraud")
domain_1 = list(range(0,100000,15000))
ax[0].set_xticks(domain_1)
df[df["FraudFound_P"] == 1]["ClaimSize"].plot.hist(ax = ax[1], bins = 20, edgecolor = "black", color = "green")
ax[1].set_title("Fraud")
domain_2 = list(range(0,100000,10000))
ax[1].set_xticks(domain_2)
plt.show()

# %%
# Claim Date

# Month Claimed

fig, ax = plt.subplots(1, 2, figsize = (18, 8))
df["MonthClaimed"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Month Claimed")
ax[0].set_ylabel("Number")
sns.countplot("MonthClaimed", hue = "FraudFound_P", data = df, ax = ax[1])
ax[1].set_title("Month Claimed on determining if a claim if Fraud or not")
plt.show()

# %%
# Claim Date

# Week of Month Claimed

fig, ax = plt.subplots(1, 2, figsize = (18, 8))
df["WeekOfMonthClaimed"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Week Of Month Claimed")
ax[0].set_ylabel("Number")
sns.countplot("WeekOfMonthClaimed", hue = "FraudFound_P", data = df, ax = ax[1])
ax[1].set_title("Week Of Month Claimed on determining if a claim if Fraud or not")
plt.show()

# %%
# Claim Date

# Day of Week Claimed

fig, ax = plt.subplots(1, 2, figsize = (18, 8))
df["DayOfWeekClaimed"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Day Of Week Claimed")
ax[0].set_ylabel("Number")
sns.countplot("DayOfWeekClaimed", hue = "FraudFound_P", data = df, ax = ax[1])
ax[1].set_title("Day Of Week Claimed on determining if a claim if Fraud or not")
plt.show()

# %%
# Effect of Policy Data on Fraud Claims( Policy Number, Policy Type, Deductible, Base Policy)

#Policy Number

fig, ax = plt.subplots(1, 2, figsize = (18, 10))
df[df["FraudFound_P"] ==0]["PolicyNumber"].plot.hist(ax = ax[0], bins = 20, edgecolor = "black", color = "blue")
ax[0].set_title("Not Fraud")
domain_1 = list(range(0,16000,2000))
ax[0].set_xticks(domain_1)
df[df["FraudFound_P"] ==1]["PolicyNumber"].plot.hist(ax = ax[1], bins = 20, edgecolor = "black", color = "green")
ax[1].set_title("Fraud")
domain_2 = list(range(0,160000,2000))
ax[1].set_xticks(domain_2)
plt.show()

# %%
# Policy Type

fig, ax = plt.subplots(1, 2, figsize = (30, 15))
df["PolicyType"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Policy Type")
ax[0].set_ylabel("Number")
sns.countplot("PolicyType", hue = "FraudFound_P", data = df, ax = ax[1])
ax[1].set_title("Policy Type Claimed on determining if a claim if Fraud or not")
plt.show()

# %%
# Deductible

fig, ax = plt.subplots(1, 2, figsize = (18, 8))
df["Deductible"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Deductible")
ax[0].set_ylabel("Number")
sns.countplot("Deductible", hue = "FraudFound_P", data = df, ax = ax[1])
ax[1].set_title("Deductible Claimed on determining if a claim if Fraud or not")
plt.show()

# %%
# Base Policy

fig, ax = plt.subplots(1, 2, figsize = (18, 8))
df["BasePolicy"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Base Policy")
ax[0].set_ylabel("Number")
sns.countplot("BasePolicy", hue = "FraudFound_P", data = df, ax = ax[1])
ax[1].set_title("Base Policy Claimed on determining if a claim if Fraud or not")
plt.show()

# %%
#Effect of Driver Rating on Fraud Claims

fig, ax = plt.subplots(1, 2, figsize = (18, 8))
df["DriverRating"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Driver Rating")
ax[0].set_ylabel("Number")
sns.countplot("DriverRating", hue = "FraudFound_P", data = df, ax = ax[1])
ax[1].set_title("DriverRating on determining if a claim if Fraud or not")
plt.show()

# %%
# Year vs Fraudulent Claims

fig, ax = plt.subplots(1, 2, figsize = (18, 8))
df["Year"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Year")
ax[0].set_ylabel("Number")
sns.countplot("Year", hue = "FraudFound_P", data = df, ax = ax[1])
ax[1].set_title("Year on determining if a claim if Fraud or not")
plt.show()

# %%
# Agent Type vs Fraudulent Claims

fig, ax = plt.subplots(1, 2, figsize = (18, 8))
df["AgentType"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Agent Type")
ax[0].set_ylabel("Number")
sns.countplot("AgentType", hue = "FraudFound_P", data = df, ax = ax[1])
ax[1].set_title("Agent Type on determining if a claim if Fraud or not")
plt.show()
